# %%
import sys
sys.path.append('..')

# %%
import numpy as np

# %%
# (1)
from CharacterCode import *

def isSmall(num):
    return num >= 97 and num <= 122

def isBig(num):
    return num >= 65 and num <= 90

def decodeChar1(ch, key):
    if ch.isalpha():
        int_num = AsciiStr2Int(ch)
        if isSmall(int_num):
            order = int_num - 97
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 97))
        if isBig(int_num):
            order = int_num - 65
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 65))
    return ch
       
def decodeText1(text, key):
    ret = ''
    for ch in text:
        ret += decodeChar1(ch, key)
    return ret

def solve1(file_path):
    with open(file_path, 'r', encoding='ascii') as f:
        tmp = f.readlines()
        txt_array = []
        for txt in tmp:
            if txt[-1] == '\n':
                txt_array.append(txt[:-1])
            else:
                txt_array.append(txt)
        for key in range(1, 26):
            print('key: ' + str(key))
            for txt in txt_array:
                print(decodeText1(txt, key))
            print('---end---\n')

# %%
# solve1('test001.txt')
# Out:
# key: 1
# Rww, iye coow dy rkfo pyexn dro pyvvygsxq coxodoxmoc.
# Yxo yp dro cswzvocd ohkwzvoc yp k celcdsdedsyx mszrob sc dro Mkockb
# mszrob, grsmr sc cksn dy rkfo loox econ li Tevsec Mkockb dy
# mywwexsmkdo gsdr rsc kbwi. Mkockb sc myxcsnobon dy lo yxo yp dro psbcd
# zobcyxc dy rkfo ofob owzvyion oxmbizdsyx pyb dro ckuo yp comebsxq
# wocckqoc. Mkockb nomsnon drkd crspdsxq okmr voddob sx dro wocckqo
# gyevn lo rsc cdkxnkbn kvqybsdrw, kxn cy ro sxpybwon kvv yp rsc
# qoxobkvc yp rsc nomscsyx, kxn gkc dr
# ---end---
#
# key: 2
# Qvv, hxd bnnv cx qjen oxdwm cqn oxuuxfrwp bnwncnwlnb.
# Xwn xo cqn brvyunbc ngjvyunb xo j bdkbcrcdcrxw lryqna rb cqn Ljnbja
# lryqna, fqrlq rb bjrm cx qjen knnw dbnm kh Sdurdb Ljnbja cx
# lxvvdwrljcn frcq qrb javh. Ljnbja rb lxwbrmnanm cx kn xwn xo cqn orabc
# ynabxwb cx qjen nena nvyuxhnm nwlahycrxw oxa cqn bjtn xo bnldarwp
# vnbbjpnb. Ljnbja mnlrmnm cqjc bqrocrwp njlq unccna rw cqn vnbbjpn
# fxdum kn qrb bcjwmjam jupxarcqv, jwm bx qn rwoxavnm juu xo qrb
# pnwnajub xo qrb mnlrbrxw, jwm fjb cq
# ---end---
#
# key: 3
# Puu, gwc ammu bw pidm nwcvl bpm nwttweqvo amvmbmvkma.
# Wvm wn bpm aquxtmab mfiuxtma wn i acjabqbcbqwv kqxpmz qa bpm Kimaiz
# kqxpmz, epqkp qa aiql bw pidm jmmv caml jg Rctqca Kimaiz bw
# kwuucvqkibm eqbp pqa izug. Kimaiz qa kwvaqlmzml bw jm wvm wn bpm nqzab
# xmzawva bw pidm mdmz muxtwgml mvkzgxbqwv nwz bpm aism wn amkczqvo
# umaaioma. Kimaiz lmkqlml bpib apqnbqvo mikp tmbbmz qv bpm umaaiom
# kirivepw sj lmw higmwmsr, erh aew xl
# ---end---
#
# key: 8
# Kpp, brx vhhp wr kdyh irxqg wkh iroorzlqj vhqhwhqfhv.
# Rqh ri wkh vlpsohvw hadpsohv ri d vxevwlwxwlrq flskhu lv wkh Fdhvdu
# flskhu, zklfk lv vdlg wr kdyh ehhq xvhg eb Mxolxv Fdhvdu wr
# frppxqlfdwh zlwk klv dupb. Fdhvdu lv frqvlghuhg wr eh rqh ri wkh iluvw
# shuvrqv wr kdyh hyhu hpsorbhg hqfubswlrq iru wkh vdnh ri vhfxulqj
# phvvdjhv. Fdhvdu ghflghg wkdw vkliwlqj hdfk ohwwhu lq wkh phvvdjh
# zrxog eh klv vwdqgdug dojrulwkp, dqg vr kh lqiruphg doo ri klv
# jhqhudov ri klv ghflvlrq, dqg zdv wk
# ---end---
#
# key: 9
# Joo, aqw uggo vq jcxg hqwpf vjg hqnnqykpi ugpgvgpegu.
# Qpg qh vjg ukornguv gzcorngu qh c uwduvkvwvkqp ekrjgt ku vjg Ecguct
# ekrjgt, yjkej ku uckf vq jcxg dggp wugf da Lwnkwu Ecguct vq
# eqoowpkecvg ykvj jku ctoa. Ecguct ku eqpukfgtgf vq dg qpg qh vjg hktuv
# rgtuqpu vq jcxg gxgt gornqagf gpetarvkqp hqt vjg ucmg qh ugewtkpi
# oguucigu. Ecguct fgekfgf vjcv ujkhvkpi gcej ngvvgt kp vjg oguucig
# yqwnf dg jku uvcpfctf cniqtkvjo, cpf uq jg kphqtogf cnn qh jku
# igpgtcnu qh jku fgekukqp, cpf ycu vj
# ---end---
#
# key: 10
# Inn, zpv tffn up ibwf gpvoe uif gpmmpxjoh tfofufodft.
# Pof pg uif tjnqmftu fybnqmft pg b tvctujuvujpo djqifs jt uif Dbftbs
# djqifs, xijdi jt tbje up ibwf cffo vtfe cz Kvmjvt Dbftbs up
# dpnnvojdbuf xjui ijt bsnz. Dbftbs jt dpotjefsfe up cf pof pg uif gjstu
# qfstpot up ibwf fwfs fnqmpzfe fodszqujpo gps uif tblf pg tfdvsjoh
# nfttbhft. Dbftbs efdjefe uibu tijgujoh fbdi mfuufs jo uif nfttbhf
# xpvme cf ijt tuboebse bmhpsjuin, boe tp if jogpsnfe bmm pg ijt
# hfofsbmt pg ijt efdjtjpo, boe xbt ui
# ---end---
#
# key: 11
# Hmm, you seem to have found the following senetences.
# One of the simplest examples of a substitution cipher is the Caesar
# cipher, which is said to have been used by Julius Caesar to
# communicate with his army. Caesar is considered to be one of the first
# persons to have ever employed encryption for the sake of securing
# messages. Caesar decided that shifting each letter in the message
# would be his standard algorithm, and so he informed all of his
# generals of his decision, and was th
# ---end---
#
# key: 12
# Gll, xnt rddl sn gzud entmc sgd enkknvhmf rdmdsdmbdr.
# Nmd ne sgd rhlokdrs dwzlokdr ne z rtarshstshnm bhogdq hr sgd Bzdrzq
# bhogdq, vghbg hr rzhc sn gzud addm trdc ax Itkhtr Bzdrzq sn
# bnlltmhbzsd vhsg ghr zqlx. Bzdrzq hr bnmrhcdqdc sn ad nmd ne sgd ehqrs
# jbhyq or uvf fgnaqneq nytbevguz, naq fb ur vasbezrq nyy bs uvf
# trarenyf bs uvf qrpvfvba, naq jnf gu
# ---end---
#
# key: 25
# Tyy, kag eqqy fa tmhq ragzp ftq raxxaiuzs eqzqfqzoqe.
# Azq ar ftq euybxqef qjmybxqe ar m egnefufgfuaz oubtqd ue ftq Omqemd
# oubtqd, ituot ue emup fa tmhq nqqz geqp nk Vgxuge Omqemd fa
# oayygzuomfq iuft tue mdyk. Omqemd ue oazeupqdqp fa nq azq ar ftq rudef
# bqdeaze fa tmhq qhqd qybxakqp qzodkbfuaz rad ftq emwq ar eqogduzs
# yqeemsqe. Omqemd pqoupqp ftmf eturfuzs qmot xqffqd uz ftq yqeemsq
# iagxp nq tue efmzpmdp mxsadufty, mzp ea tq uzradyqp mxx ar tue
# sqzqdmxe ar tue pqoueuaz, mzp ime ft
# ---end---

# %%
# (2)
from CharacterCode import *

def isSmall(num):
    return num >= 97 and num <= 122

def isBig(num):
    return num >= 65 and num <= 90

def decodeChar1(ch, key):
    if ch.isalpha():
        int_num = AsciiStr2Int(ch)
        if isSmall(int_num):
            order = int_num - 97
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 97))
        if isBig(int_num):
            order = int_num - 65
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 65))
    return ch
       
def decodeText1(text, key):
    ret = ''
    for ch in text:
        ret += decodeChar1(ch, key)
    return ret

class Tmp(object):
    def __init__(self, al, cnt):
        self.al = al
        self.cnt = cnt
    def __repr__(self):
        return '{0}: {1}'.format(self.al, self.cnt)
    def __lt__(self, tmp):
        return self.cnt < tmp.cnt    

def solve2_1(file_path):
    with open(file_path, 'r', encoding='ascii') as f:
        text = f.read().lower()
        freq = []
        for i in range(26):
            order = i + 97
            al = Hexbytes2Str(Int2hexbytes(order))
            cnt = 0
            tmp = Tmp(al, cnt)
            freq.append(tmp)
        for ch in text:
            if ch.isalpha():
                idx = AsciiStr2Int(ch) - 97
                freq[idx].cnt += 1
        freq.sort()
        freq = freq[::-1]
        for tmp in freq:
            print(tmp)

# %%
# solve2_1('test001.txt')
# Out:
# p: 56
# d: 39
# t: 30
# z: 29
# l: 29
# e: 28
# s: 25
# y: 22
# c: 19
# o: 16
# n: 16
# x: 13
# w: 12
# q: 12
# f: 10
# r: 7
# a: 7
# m: 5
# j: 5
# h: 5
# g: 4
# v: 1
# u: 1
# i: 1
# k: 0
# b: 0

# %%
from CharacterCode import *

def isSmall(num):
    return num >= 97 and num <= 122

def isBig(num):
    return num >= 65 and num <= 90

def decodeChar1(ch, key):
    if ch.isalpha():
        int_num = AsciiStr2Int(ch)
        if isSmall(int_num):
            order = int_num - 97
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 97))
        if isBig(int_num):
            order = int_num - 65
            return Hexbytes2Str(Int2hexbytes((order - key) % 26 + 65))
    return ch
       
def decodeText1(text, key):
    ret = ''
    for ch in text:
        ret += decodeChar1(ch, key)
    return ret

class Tmp(object):
    def __init__(self, al, cnt):
        self.al = al
        self.cnt = cnt
    def __repr__(self):
        return '{0}: {1}'.format(self.al, self.cnt)
    def __lt__(self, tmp):
        return self.cnt < tmp.cnt    

def solve2_2(file_path):
    with open(file_path, 'r', encoding='ascii') as f:
        text = f.read().lower()
        freq = []
        for i in range(26):
            order = i + 97
            al = Hexbytes2Str(Int2hexbytes(order))
            cnt = 0
            tmp = Tmp(al, cnt)
            freq.append(tmp)
        for ch in text:
            if ch.isalpha():
                idx = AsciiStr2Int(ch) - 97
                freq[idx].cnt += 1
        freq.sort()
        freq = freq[::-1]
        for tmp in freq:
            print(tmp)
# Out:
# [0, 3]

# %%
from CharacterCode import *
from PriorityQueue import PriorityQueue

def isSmall(num):
    return num >= 97 and num <= 122

def isBig(num):
    return num >= 65 and num <= 90

freq = []

class Node(object):
    # 文字の場合node_idはasciiコード
    def __init__(self, al, cnt, node_id):
        self.al = al
        self.cnt = cnt
        self.node_id = node_id
        # parent, left, rightのnode_id 
        self.p = None
        self.r = None
        self.l = None
    def __repr__(self):                           
        return '{0}: {1}, ID: {2}\n'.format(self.al, self.cnt, self.node_id) + \
               '親ノード: {0}\n'.format(self.p) + \
               '左ノード: {0}, 右ノード: {1}'.format(self.l, self.r)
    def __lt__(self, node):
        if self.cnt == node.cnt:
            return self.node_id < node.node_id
        else:
            return self.cnt < node.cnt 

def encode3(ch):
    ret = ''
    global freq
    node = freq[AsciiStr2Int(ch)]
    while True:
        if node.p == None:
            break
        p = freq[node.p]
        if p.l == node.node_id:
            ret += '0'
        elif p.r == node.node_id:
            ret += '1'
        node = p
    return ret[::-1]        
        
def solve3_1(file_path):
    with open(file_path, 'r', encoding='ascii') as f:
        text = f.read().lower()
        global freq
        freq = [None for _ in range(127)]
        for i in range(127):
            if i == 10:
                node = Node('LF', 0, i)
                freq[i] = node
            elif i == 13:
                node = Node('CR', 0, i)
                freq[i] = node
            elif i == 32:
                node = Node('SP', 0, i)
            elif i >= 33 and i <= 126:
                al = Hexbytes2Str(Int2hexbytes(i))
                cnt = 0
                node = Node(al, cnt, i)            
                freq[i] = node
        for ch in text:
            if ch.isalpha():
                idx = AsciiStr2Int(ch)
                freq[idx].cnt += 1
        pq = PriorityQueue([])
        for node in freq:
            if node != None:
                pq.push(node)
        while len(pq) > 1:
            new_node_id = len(freq)
            r_node = pq.pop()
            l_node = pq.pop()
            new_node = Node('{0},{1}'.format(r_node.al, l_node.al), r_node.cnt + l_node.cnt, new_node_id)
            r_node.p = new_node_id
            l_node.p = new_node_id
            new_node.r = r_node.node_id
            new_node.l = l_node.node_id
            freq.append(new_node)
            pq.push(new_node)
        for i in range(127):
            node = freq[i]
            if node != None:
                code = None
                if node.al == 'LF':
                    code = encode3('\n')
                elif node.al == 'CR':
                    code = encode3('\r')
                elif node.al == 'SP':
                    code = encode3(' ')
                else:
                    code = encode3(node.al)
                print('{0}: {1}'.format(node.al, code))

# %%
solve3_1('test001.txt')
# Out:
# LF: 0000101110001111
# CR: 0000101110001110
# !: 0000101110001101
# ": 0000101110001100
# #: 0000101110001011
# $: 0000101110001010
# %: 0000101110001001
# &: 0000101110001000
# ': 0000101110000111
# (: 0000101110000110
# ): 0000101110000101
# *: 0000101110000100
# +: 0000101110000011
# ,: 0000101110000010
# -: 0000101110000001
# .: 0000101110000000
# /: 000010111111111
# 0: 000010111111110
# 1: 000010111111101
# 2: 000010111111100
# 3: 000010111111011
# 4: 000010111111010
# 5: 000010111111001
# 6: 000010111111000
# 7: 000010111110111
# 8: 000010111110110
# 9: 000010111110101
# :: 000010111110100
# ;: 000010111110011
# <: 000010111110010
# =: 000010111110001
# >: 000010111110000
# ?: 000010111101111
# @: 000010111101110
# A: 000010111101101
# B: 000010111101100
# C: 000010111101011
# D: 000010111101010
# E: 000010111101001
# F: 000010111101000
# G: 000010111100111
# H: 000010111100110
# I: 000010111100101
# J: 000010111100100
# K: 000010111100011
# L: 000010111100010
# M: 000010111100001
# N: 000010111100000
# O: 000010111011111
# P: 000010111011110
# Q: 000010111011101
# R: 000010111011100
# S: 000010111011011
# T: 000010111011010
# U: 000010111011001
# V: 000010111011000
# W: 000010111010111
# X: 000010111010110
# Y: 000010111010101
# Z: 000010111010100
# [: 000010111010011
# \: 000010111010010
# ]: 000010111010001
# ^: 000010111010000
# _: 000010111001111
# `: 000010111001110
# a: 011110
# b: 000010111001101
# c: 1110
# d: 110
# e: 0110
# f: 10111
# g: 0000100
# h: 101101
# i: 000010110
# j: 101100
# k: 000010111001100
# l: 0011
# m: 011111
# n: 00000
# o: 1111
# p: 010
# q: 10011
# r: 000011
# s: 1000
# t: 0001
# u: 000010101
# v: 000010100
# w: 10010
# x: 01110
# y: 1010
# z: 0010
# {: 000010111001011
# |: 000010111001010
# }: 000010111001001
# ~: 000010111001000

# %%
def test_make_graph():
    a = Node('A', 50, 65)
    b = Node('B', 20, 66)
    c = Node('C', 33, 67)
    d = Node('D', 15, 68)
    e = Node('E', 40, 69)
    global freq
    freq = [None for _ in range(127)]
    freq[65] = a
    freq[66] = b
    freq[67] = c
    freq[68] = d
    freq[69] = e       
    pq = PriorityQueue([])
    pq.push(a)
    pq.push(b)
    pq.push(c)
    pq.push(d)
    pq.push(e)
    new_node_id = 127
    while len(pq) > 1:
        new_node_id = len(freq)
        r_node = pq.pop()
        l_node = pq.pop()
        new_node = Node('{0},{1}'.format(r_node.al, l_node.al), r_node.cnt + l_node.cnt, new_node_id)
        r_node.p = new_node_id
        l_node.p = new_node_id
        new_node.r = r_node.node_id
        new_node.l = l_node.node_id
        freq.append(new_node)
        pq.push(new_node)          
    print(freq)
    
def encode3(ch):
    ret = ''
    node = freq[AsciiStr2Int(ch)]
    while True:
        if node.p == None:
            break
        p = freq[node.p]
        if p.l == node.node_id:
            ret += '0'
        elif p.r == node.node_id:
            ret += '1'
        node = p
    return ret[::-1]

# %%
test_make_graph()
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, A: 50, ID: 65
# 親ノード: 129
# 左ノード: None, 右ノード: None, B: 20, ID: 66
# 親ノード: 127
# 左ノード: None, 右ノード: None, C: 33, ID: 67
# 親ノード: 128
# 左ノード: None, 右ノード: None, D: 15, ID: 68
# 親ノード: 127
# 左ノード: None, 右ノード: None, E: 40, ID: 69
# 親ノード: 129
# 左ノード: None, 右ノード: None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, D,B: 35, ID: 127
# 親ノード: 128
# 左ノード: 66, 右ノード: 68, C,D,B: 68, ID: 128
# 親ノード: 130
# 左ノード: 127, 右ノード: 67, E,A: 90, ID: 129
# 親ノード: 130
# 左ノード: 65, 右ノード: 69, C,D,B,E,A: 158, ID: 130
# 親ノード: None
# 左ノード: 129, 右ノード: 128]

# %%
from CharacterCode import *
from PriorityQueue import PriorityQueue

def isSmall(num):
    return num >= 97 and num <= 122

def isBig(num):
    return num >= 65 and num <= 90

freq = []

class Node(object):
    # 文字の場合node_idはasciiコード
    def __init__(self, al, cnt, node_id):
        self.al = al
        self.cnt = cnt
        self.node_id = node_id
        # parent, left, rightのnode_id 
        self.p = None
        self.r = None
        self.l = None
    def __repr__(self):                           
        return '{0}: {1}, ID: {2}\n'.format(self.al, self.cnt, self.node_id) + \
               '親ノード: {0}\n'.format(self.p) + \
               '左ノード: {0}, 右ノード: {1}'.format(self.l, self.r)
    def __lt__(self, node):
        if self.cnt == node.cnt:
            return self.node_id < node.node_id
        else:
            return self.cnt < node.cnt 

def encode3(ch):
    ret = ''
    global freq
    node = freq[AsciiStr2Int(ch)]
    while True:
        if node.p == None:
            break
        p = freq[node.p]
        if p.l == node.node_id:
            ret += '0'
        elif p.r == node.node_id:
            ret += '1'
        node = p
    return ret[::-1]        
        
def solve3_2(file_path):
    with open(file_path, 'r', encoding='ascii') as f:
        text = f.read().lower()
        global freq
        freq = [None for _ in range(127)]
        for i in range(127):
            if i == 10:
                node = Node('LF', 0, i)
                freq[i] = node
            elif i == 13:
                node = Node('CR', 0, i)
                freq[i] = node
            elif i == 32:
                node = Node('SP', 0, i)
            elif i >= 33 and i <= 126:
                al = Hexbytes2Str(Int2hexbytes(i))
                cnt = 0
                node = Node(al, cnt, i)            
                freq[i] = node
        for ch in text:
            if ch.isalpha():
                idx = AsciiStr2Int(ch)
                freq[idx].cnt += 1
        pq = PriorityQueue([])
        for node in freq:
            if node != None:
                pq.push(node)
        while len(pq) > 1:
            new_node_id = len(freq)
            r_node = pq.pop()
            l_node = pq.pop()
            new_node = Node('{0},{1}'.format(r_node.al, l_node.al), r_node.cnt + l_node.cnt, new_node_id)
            r_node.p = new_node_id
            l_node.p = new_node_id
            new_node.r = r_node.node_id
            new_node.l = l_node.node_id
            freq.append(new_node)
            pq.push(new_node)
        dic = {}    
        for i in range(127):
            node = freq[i]
            if node != None:
                code = None
                if node.al == 'LF':
                    code = encode3('\n')
                elif node.al == 'CR':
                    code = encode3('\r')
                elif node.al == 'SP':
                    code = encode3(' ')
                else:
                    code = encode3(node.al)
                dic[node.al] = len(code)
        total = 0
        mom = 0
        for i in range(127):
            node = freq[i]
            if node != None:
                cnt = node.cnt
                size = dic[node.al]
                total += (cnt * size)
                mom += cnt
        print('{0:.2f}'.format(total / mom))

# %%
solve3_2('test001.txt')
# Out:
# 4.14
